# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## EDA using Univariate Analysis :-

# %%
df = pd.read_csv('titanic.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print("Minimum : ",df['Age'].min())
print("Maximum : ",df['Age'].max())
# Out:
# Minimum :  0.42
# Maximum :  80.0

# %%
print("Mean :",df['Age'].mean())
print("Mean :",df['Age'].median())
print("Mode :",df['Age'].mode())
# Out:
# Mean : 29.69911764705882
# Mean : 28.0
# Mode : 0    24.0
# Name: Age, dtype: float64

# %%
df['Age'].skew() # Positive Skew
# Out:
# 0.38910778230082704

# %% [markdown]
# ## Categorical Data :-

# %% [markdown]
# ### a. Countplot :

# %%
sns.countplot(x=df['Survived'],color='green')
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x=df['Pclass'],palette='hot')
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_25680\3741358474.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Pclass'],palette='hot')
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x=df['Sex'],palette='cool')
df['Sex'].value_counts()
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_25680\1258082891.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Sex'],palette='cool')
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %% [markdown]
# ### b. Pie Chart :

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ## Numerical Data :-

# %% [markdown]
# ### a. Histogram :

# %%
plt.hist(x=df['Age'])
plt.xlabel('Age of Passengers')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# ### b. Distplot :

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_25680\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ### c. Boxplot :

# %%
sns.boxplot(x=df['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>
