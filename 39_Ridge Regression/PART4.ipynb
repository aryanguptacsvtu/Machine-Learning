# %%
from sklearn.datasets import load_diabetes
from sklearn.metrics import r2_score
import numpy as np
from sklearn.model_selection import train_test_split

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=4)

# %% [markdown]
# ## Using SGDRegressor :

# %%
from sklearn.linear_model import SGDRegressor

# %%
reg = SGDRegressor(penalty='l2',max_iter=500,eta0=0.1,learning_rate='constant',alpha=0.001)

# %%
reg.fit(X_train,y_train)

print("Coefficients :\n",reg.coef_)
print("\nIntercept :",reg.intercept_)
# Out:
# Coefficients :
#  [  50.58269415 -156.21176794  367.30109514  274.76382716   -5.42496494
#   -58.06520847 -171.2365102   140.29627706  332.86010107   99.10762051]
#
# Intercept : [145.07715885]

# %%
y_pred = reg.predict(X_test)
print("R2 score :",r2_score(y_test,y_pred))
# Out:
# R2 score : 0.4377677872410527

# %% [markdown]
# ## Using Ridge Regression :

# %%
from sklearn.linear_model import Ridge

# %%
reg = Ridge(alpha=0.001, max_iter=500,solver='sparse_cg')

# %%
reg.fit(X_train,y_train)

print("Coefficients :\n",reg.coef_)
print("\nIntercept :",reg.intercept_)
# Out:
# Coefficients :
#  [  34.52192544 -290.84084076  482.40181344  368.0678662  -852.44873179
#   501.59160336  180.11115788  270.76333979  759.73534372   37.4913546 ]
#
# Intercept : 151.10198517439466

# %%
y_pred = reg.predict(X_test)
print("R2 score :",r2_score(y_test,y_pred))
# Out:
# R2 score : 0.46250101619914563

# %% [markdown]
# ## Creating Ridge Regression (+ GD) Class :
# For n-dimensional Data

# %%
class MyRidgeGD:
    
    def __init__(self,epochs,learning_rate,alpha):
        self.learning_rate = learning_rate
        self.epochs = epochs
        self.alpha = alpha
        self.coef_ = None
        self.intercept_ = None
        
    def fit(self,X_train,y_train):
        
        self.coef_ = np.ones(X_train.shape[1])
        self.intercept_ = 0
        thetha = np.insert(self.coef_,0,self.intercept_)
        
        X_train = np.insert(X_train,0,1,axis=1)
        
        for i in range(self.epochs):
            thetha_der = np.dot(X_train.T,X_train).dot(thetha) - np.dot(X_train.T,y_train) + self.alpha*thetha
            thetha = thetha - self.learning_rate*thetha_der
        
        self.coef_ = thetha[1:]
        self.intercept_ = thetha[0]

    
    def predict(self,X_test):
        return np.dot(X_test,self.coef_) + self.intercept_

# %%
reg = MyRidgeGD(epochs=500,alpha=0.001,learning_rate=0.005)

# %%
reg.fit(X_train,y_train)

print("Coefficients :\n",reg.coef_)
print("\nIntercept :",reg.intercept_)
# Out:
# Coefficients :
#  [  46.65050914 -221.3750037   452.12080647  325.54248128  -29.09464178
#   -96.47517735 -190.90017011  146.32900372  400.80267299   95.09048094]
#
# Intercept : 150.86975316713466

# %%
y_pred = reg.predict(X_test)
print("R2 score :",r2_score(y_test,y_pred))
# Out:
# R2 score : 0.4738018280260913
